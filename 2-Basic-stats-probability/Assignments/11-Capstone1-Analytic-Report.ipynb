# %% [markdown]
# ### An Analytic Report and Research Proposal on a dataset of your choosing

# %% [markdown]
# 1 - Describe your dataset.
# Describe and explore your dataset in the initial section of your Report.
# * What does your data contain and what is its background?
# * Where does it come from?
# * Why is it interesting or significant?
# * Conduct summary statistics and produce visualizations for the particular variables from the dataset that you will use.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

data = pd.read_csv('datasets/FEMA-database.csv')
data.head(20)
# Out:
#    Declaration_Number Declaration_Type Declaration_Date State County  \
# 0                DR-1         Disaster       05/02/1953    GA    NaN
# 1                DR-2         Disaster       05/15/1953    TX    NaN
# 2                DR-3         Disaster       05/29/1953    LA    NaN
# 3                DR-4         Disaster       06/02/1953    MI    NaN
# 4                DR-5         Disaster       06/06/1953    MT    NaN
# 5                DR-6         Disaster       06/09/1953    MI    NaN
# 6                DR-7         Disaster       06/11/1953    MA    NaN
# 7                DR-8         Disaster       06/11/1953    IA    NaN
# 8                DR-9         Disaster       06/19/1953    TX    NaN
# 9               DR-11         Disaster       07/02/1953    NH    NaN
# 10              DR-12         Disaster       10/22/1953    FL    NaN
# 11              DR-13         Disaster       10/30/1953    AK    NaN
# 12              DR-14         Disaster       12/06/1953    MS    NaN
# 13              DR-15         Disaster       02/05/1954    CA    NaN
# 14              DR-16         Disaster       03/17/1954    GA    NaN
# 15              DR-17         Disaster       06/23/1954    IA    NaN
# 16              DR-18         Disaster       07/01/1954    TX    NaN
# 17              DR-19         Disaster       07/14/1954    NV    NaN
# 18              DR-20         Disaster       07/31/1954    SD    NaN
# 19              DR-21         Disaster       08/04/1954    WV    NaN
#
#    Disaster_Type              Disaster_Title  Start_Date    End_Date  \
# 0        Tornado                     Tornado  05/02/1953  05/02/1953
# 1        Tornado  Tornado and Heavy Rainfall  05/15/1953  05/15/1953
# 2          Flood                       Flood  05/29/1953  05/29/1953
# 3        Tornado                     Tornado  06/02/1953  06/02/1953
# 4          Flood                      Floods  06/06/1953  06/06/1953
# 5        Tornado                     Tornado  06/09/1953  06/09/1953
# 6        Tornado                     Tornado  06/11/1953  06/11/1953
# 7          Flood                       Flood  06/11/1953  06/11/1953
# 8          Flood                       Flood  06/19/1953  06/19/1953
# 9           Fire                 Forest Fire  07/02/1953  07/02/1953
# 10         Flood                       Flood  10/22/1953  10/22/1953
# 11         Other             Severe Hardship  10/30/1953  10/30/1953
# 12       Tornado                     Tornado  12/06/1953  12/06/1953
# 13         Flood           Flood and Erosion  02/05/1954  02/05/1954
# 14       Tornado                     Tornado  03/17/1954  03/17/1954
# 15         Flood                       Flood  06/23/1954  06/23/1954
# 16         Flood                       Flood  07/01/1954  07/01/1954
# 17    Earthquake                  Earthquake  07/14/1954  07/14/1954
# 18         Flood                       Flood  07/31/1954  07/31/1954
# 19         Flood                       Flood  08/04/1954  08/04/1954
#
#     Close_Date Individual_Assistance_Program Individuals_Households_Program  \
# 0   06/01/1954                           Yes                             No
# 1   01/01/1958                           Yes                             No
# 2   02/01/1960                           Yes                             No
# 3   02/01/1956                           Yes                             No
# 4   12/01/1955                           Yes                             No
# 5   03/30/1956                           Yes                             No
# 6   06/01/1956                           Yes                             No
# 7   11/01/1955                           Yes                             No
# 8   01/01/1958                           Yes                             No
# 9   02/01/1956                           Yes                             No
# 10  05/01/1956                           Yes                             No
# 11  09/01/1957                           Yes                             No
# 12  06/01/1956                           Yes                             No
# 13  09/01/1957                           Yes                             No
# 14  11/01/1956                           Yes                             No
# 15  02/01/1956                           Yes                             No
# 16  07/01/1959                           Yes                             No
# 17  08/01/1957                           Yes                             No
# 18  02/01/1956                           Yes                             No
# 19  05/01/1957                           Yes                             No
#
#    Public_Assistance_Program Hazard_Mitigation_Program
# 0                        Yes                       Yes
# 1                        Yes                       Yes
# 2                        Yes                       Yes
# 3                        Yes                       Yes
# 4                        Yes                       Yes
# 5                        Yes                       Yes
# 6                        Yes                       Yes
# 7                        Yes                       Yes
# 8                        Yes                       Yes
# 9                        Yes                       Yes
# 10                       Yes                       Yes
# 11                       Yes                       Yes
# 12                       Yes                       Yes
# 13                       Yes                       Yes
# 14                       Yes                       Yes
# 15                       Yes                       Yes
# 16                       Yes                       Yes
# 17                       Yes                       Yes
# 18                       Yes                       Yes
# 19                       Yes                       Yes

# %%
data.Disaster_Type.value_counts().head(10).plot(kind='bar')
plt.ylabel('Artworks Count')
# Out:
# Text(0, 0.5, 'Artworks Count')

# %%
data.Disaster_Title.value_counts().head(50).plot(kind='bar')
plt.ylabel('Artworks Count')
# Out:
# Text(0, 0.5, 'Artworks Count')

# %% [markdown]
# 2 - Ask and answer analytic questions.
# * Ask three analytic questions and answer each one with a combination of statistics and visualizations.
# * These analytic questions can focus on individuals behaviors or comparisons of the population.

# %% [markdown]
# 3 - Propose further research.
# * Lastly, make a proposal for a realistic future research project on this dataset that would use some data science techniques you'd like to learn in the bootcamp.
# * Just like your earlier questions, your research proposal should present one or more clear questions.
# * Then you should describe the techniques you would apply in order to arrive at an answer.

# %% [markdown]
# An example: https://medium.com/@jasoncrease/was-2016-especially-dangerous-for-celebrities-79d79b9fae02#.zd8hv5jge

# %% [markdown]
# Rubric for grading: https://docs.google.com/spreadsheets/d/18Z0aaE6mWIhUomdzfVZqYeAzw51-iEz_lGHIPwM-3ls/edit#gid=0
